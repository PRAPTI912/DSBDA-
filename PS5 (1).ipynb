# %%
import pandas as pd

# Load Iris dataset
df = pd.read_csv(r"C:\Users\Prapti\OneDrive\Desktop\DSBDA labs\datasets\13Iris.csv")

# Get summary statistics for numeric variables grouped by 'species'
summary = df.groupby('species').agg(
    sepal_length_mean=('SepalLengthCm', 'mean'),
    sepal_length_median=('SepalLengthCm', 'median'),
    sepal_length_min=('SepalLengthCm', 'min'),
    sepal_length_max=('SepalLengthCm', 'max'),
    sepal_length_std=('SepalLengthCm', 'std'),
    sepal_width_mean=('SepalWidthCm', 'mean'),
    sepal_width_median=('SepalWidthCm', 'median'),
    sepal_width_min=('SepalWidthCm', 'min'),
    sepal_width_max=('SepalWidthCm', 'max'),
    sepal_width_std=('SepalWidthCm', 'std')
)

# Display the summary statistics
print(summary)
# Out:
#                  sepal_length_mean  sepal_length_median  sepal_length_min  \
# species
# Iris-setosa                  5.006                  5.0               4.3
# Iris-versicolor              5.936                  5.9               4.9
# Iris-virginica               6.588                  6.5               4.9
#
#                  sepal_length_max  sepal_length_std  sepal_width_mean  \
# species
# Iris-setosa                   5.8          0.352490             3.418
# Iris-versicolor               7.0          0.516171             2.770
# Iris-virginica                7.9          0.635880             2.974
#
#                  sepal_width_median  sepal_width_min  sepal_width_max  \
# species
# Iris-setosa                     3.4              2.3              4.4
# Iris-versicolor                 2.8              2.0              3.4
# Iris-virginica                  3.0              2.2              3.8
#
#                  sepal_width_std
# species
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.groupby(["species"])["SepalLengthCm"].mean()
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
# Create a dictionary where species is the key, and the list of sepal_length is the value
species_sepal_length = df.groupby('species')['SepalLengthCm'].apply(list).to_dict()

# Display the lists
print(species_sepal_length)
# Out:
# {'Iris-setosa': [5.1, 4.9, 4.7, 4.6, 5.0, 5.4, 4.6, 5.0, 4.4, 4.9, 5.4, 4.8, 4.8, 4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5.0, 5.0, 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5.0, 5.5, 4.9, 4.4, 5.1, 5.0, 4.5, 4.4, 5.0, 5.1, 4.8, 5.1, 4.6, 5.3, 5.0], 'Iris-versicolor': [7.0, 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5.0, 5.9, 6.0, 6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6, 6.8, 6.7, 6.0, 5.7, 5.5, 5.5, 5.8, 6.0, 5.4, 6.0, 6.7, 6.3, 5.6, 5.5, 5.5, 6.1, 5.8, 5.0, 5.6, 5.7, 5.7, 6.2, 5.1, 5.7], 'Iris-virginica': [6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8, 5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6.0, 6.9, 5.6, 7.7, 6.3, 6.7, 7.2, 6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6.0, 6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9]}

# %%
a=df.groupby(["species"])["SepalLengthCm"].mean()
print(a)
# Out:
# species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
b=df.groupby(["species"])["SepalLengthCm"].median()
print(b)
# Out:
# species
# Iris-setosa        5.0
# Iris-versicolor    5.9
# Iris-virginica     6.5
# Name: SepalLengthCm, dtype: float64

# %%
list=[a,b]
print(list)
# Out:
# [species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64, species
# Iris-setosa        5.0
# Iris-versicolor    5.9
# Iris-virginica     6.5
# Name: SepalLengthCm, dtype: float64]

# %%
print('Iris-setosa')
setosa = df['species'] == 'Iris-setosa'
print(df[setosa].describe())
print('\nIris-versicolor')
setosa = df['species'] == 'Iris-versicolor'
print(df[setosa].describe())
print('\nIris-virginica')
setosa = df['species'] == 'Iris-virginica'
print(df[setosa])
print(df[setosa].describe())
# Out:
# Iris-setosa
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000
#
# Iris-versicolor
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# ...
